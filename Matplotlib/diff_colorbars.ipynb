# %%
"""
Author:Utkarsh Sharma(sharmautkarsh2396@gmail.com)
Date: 2021-09-02 01:11:00
Last Modified by:----
Last Modified time:----
Title : Write a Python programming to display a bar chart of the popularity of programming
Languages. Use different color for each bar.
"""
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

languages=np.array(['Java','Python', 'PHP', 'JavaScript', 'C#', 'C++'])
popularity_pts=np.array([22.2, 17.6, 8.8, 8, 7.7, 6.7])

# %%
plt.bar(x=languages,height=popularity_pts,color=['violet','indigo','blue','green','yellow','orange'],edgecolor='black')
plt.show()
